# %%
print("Hello word")
# Out:
# Hello word

# %%
102Mc = "disciplina legal"
# Out:
#   Cell In[3], line 1
#     102Mc = "disciplina legal"
#       ^
# SyntaxError: invalid decimal literal

# %%
class = "MC102"

# %%
print("Olá turma!");
print("Vamos programar em Python")
# Out:
# Olá turma!
# Vamos programar em Python

# %%
altura = 180
lagura = 3
idade = 19

# %%
a = 10
b = 11
c = 10
b = 20

# %%
print(a)
# Out:
# 10

# %%
a = 10
b = 10
a = a+b
print(a)
a = a+c

# %%
0.1 + 0.2
# Out:
# 0.01

# %%
print(4200)
print(42,000)
print(42.00)
# Out:
# 4200
# 42 0
# 42.0

# %%
a = 5

# %%
a = "Gabryel"

# %%
d = 3 
c = 2
b = 4 
d = c +b
a = d +1
a = a +1

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print("altura =", altura, "lagura =", lagura, "idade =", idade)
# Out:
# altura = 180 lagura = 3 idade = 19
