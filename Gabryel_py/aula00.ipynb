# %%
print("Hello word")
# Out:
# Hello word

# %%
102Mc = "disciplina legal"
# Out:
#   Cell In[3], line 1
#     102Mc = "disciplina legal"
#       ^
# SyntaxError: invalid decimal literal

# %%
class = "MC102"

# %%
print("Olá turma!");
print("Vamos programar em Python")
# Out:
# Olá turma!
# Vamos programar em Python

# %%
altura = 180
lagura = 3
idade = 19

# %%
a = 10
b = 11
c = 10
b = 20

# %%
print(a)
# Out:
# 10

# %%
a = 10
b = 10
a = a+b
print(a)
a = a+c

# %%
0.1 + 0.2
# Out:
# 0.01

# %%
print(4200)
print(42,000)
print(42.00)
# Out:
# 4200
# 42 0
# 42.0

# %%
a = 5

# %%
a = "Gabryel"

# %%
d = 3 
c = 2
b = 4 
d = c +b
a = d +1
a = a +1

# %%
d = 3.0
c = 2.5
b = 4
d = b + 90
e = c*d
a = a + 1
print(a)
print(e)
# Out:
# 9
# 235.0

# %%
nome = "Gabryel"
idade = 19
print("Olá turma, meu nome é ", nome, "eu tenho ", idade, "anos, muito prazer em conhecê-los")
# Out:
# Olá turma, meu nome é  Gabryel eu tenho  19 anos, muito prazer em conhecê-los

# %%
print("Olá turma, meu nome é "+ str(nome)+ " eu tenho "+ str(idade)+ " anos, muito prazer em conhecê-los")
# Out:
# Olá turma, meu nome é Gabryeleu tenho 19 anos, muito prazer em conhecê-los

# %%
idade = str(idade)

# %%
nome = "Gabryel"
print(nome*3)
# Out:
# GabryelGabryelGabryel

# %%
print("3,", end= "")
print("4,", end= "")
print("5,", end= "")
# Out:
# 3,4,5,

# %%
print("Digite um numero ")
numero = int(input())
print("O numero digitado foi", numero)
# Out:
# Digite um numero
# O numero digitado foi 5

# %%
print("Digite um numero ")
numero = int(input())
numero = numero*10
print("Esse numero vezes 10 é", numero)
# Out:
# Digite um numero
# Esse numero vezes 10 é 50

# %%
n1 = float(input("Digite um número"))
n2 = float(input("Digite um número"))
print("A soma desses dois numero é: %.2f" %(n1 + n2))
print("A media desses dois numero é: %.2f" %((n1 + n2)/2))
# Out:
# A soma desses dois numero é: 10.00
# A media desses dois numero é: 5.00

# %%
segundos_str = input("Por favor, digite o número de segundos que deseja converter: ")
total_segundos = int (segundos_str)
horas = total_segundos //3600
segundos_restantes = total_segundos % 3600
minutos = segundos_restantes // 60
segundos_restantes_final = segundos_restantes %60
print("Horas =", horas,"minutos =",minutos,"segundos =",segundos_restantes_final)
# Out:
# Horas = 24 minutos = 17 segundos = 6

# %%
segundos_str = input("Por favor, digite o número de segundos que deseja converter: ")
print(segundos_str)
print(type(segundos_str))
total_segundos = int (segundos_str)

horas = total_segundos //3600
print(horas)


segundos_restantes = total_segundos % 3600
minutos = segundos_restantes // 60
print(minutos)
segundos_restantes_final = segundos_restantes %60
print(segundos_restantes_final)

print("Horas =", horas,"minutos =",minutos,"segundos =",segundos_restantes_final)
# Out:
# 8460
# <class 'str'>
# 2
# 21
# 0
# Horas = 2 minutos = 21 segundos = 0

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print("altura =", altura, "lagura =", lagura, "idade =", idade)
# Out:
# altura = 180 lagura = 3 idade = 19
